# %%
# Start writing code here...

# %% [markdown]
# https://docs.google.com/presentation/d/1m8HuoTP3x0z5BFSXBLGJtyWFHDPaswVsIPHXtI7cNEU/edit#slide=id.ga701e047e1_0_0

# %% [markdown]
#  time distribution of crime, suspect/victim data, crime type & location
